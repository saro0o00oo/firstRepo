# %% [markdown]
# # change jupyter theme

# %%
# !pip install jupyterthemes
# !jt -t monokai
#revert back to default
# !jt -r

# %% [markdown]
# # numpy

# %% [markdown]
# linear algebra

# %%
import numpy as np

# %% [markdown]
# # pandas

# %% [markdown]
# data processing, CSV file I/O (e.g. pd.read_csv)
# <br> pandas is built on top of numpy

# %%
import pandas as pd

# %%
#create a pd.DataFrame
train_df = pd.read_csv('train_Titanic.csv')

# %%
#pandas.DataFrame.head(self: ~FrameOrSeries, n: int = 5)
#Return the first n rows.
train_df.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
#pandas.DataFrame.info( verbose=None,buf=None,max_cols=None,memory_usage=None,null_counts=None,)
#Print a concise summary of a DataFrame.
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#pandas.DataFrame.isnull()-> returns bool or array-like of bool
#Detect missing values for an array-like object. 
#NAN: Not A Number
train_df.isnull().sum()
#or
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#pandas.DataFrame.describe(self: ~FrameOrSeries, percentiles=None, include=None, exclude=None)
#Generate descriptive statistics, excluding NaN values.Analyzes both numeric and object series,as well as mixed data types. 
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import numpy as np
train_df.describe(include=[np.object])
# Out:
#                         Name   Sex    Ticket Cabin Embarked
# count                    891   891       891   204      889
# unique                   891     2       681   147        3
# top     Sagesser, Mlle. Emma  male  CA. 2343    G6        S
# freq                       1   577         7     4      644

# %%
train_df.describe(include=[np.number])
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_df.describe(exclude=[np.number])
# Out:
#                         Name   Sex    Ticket Cabin Embarked
# count                    891   891       891   204      889
# unique                   891     2       681   147        3
# top     Sagesser, Mlle. Emma  male  CA. 2343    G6        S
# freq                       1   577         7     4      644

# %% [markdown]
# # Data Visulalization

# %% [markdown]
# seaborn is built on top of matplotlib
# <br> seaborn is more graphical and user friendly

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Missing Values

# %%
#plot the missing values
plt.figure(figsize=(10,8)) #size of the figure
plt.title('Missing Values', y=1.05, size=15) #title of the figure
h = sns.heatmap(train_df.isnull(), cmap="viridis")
h.set_xticklabels(h.get_xticklabels(), rotation = 45, fontsize = 10);

# %% [markdown]
# ### Correlation
# Correlation is the measure of how two features are, well, correlated; just like the month-of-the-year is correlated with the average daily temperature. The hour-of-the-day is correlated with the amount of light outdoors

# %% [markdown]
# How to measure the correlation between two __continuous__ features:
# <br> The output is in the range of [-1,1].
#
# <div>
# <img src="attachment:image.png" width="200"/>
# </div>

# %%
#plot the correlation of all features
plt.figure(figsize=(12, 8))
plt.title('Correlation of Features', y=1.05, size=15)
h = sns.heatmap(abs(train_df.corr()), square=True, linewidths=0.1, linecolor='white', annot=True, vmax=1.0)
#square: display it square-shaped
#linewiths and linecolor: Width and color of the lines that divide each cell
#annot: if True, write the data value in each cell
#vmax, vmin: values to anchor the colormap, otherwise they are inferred from the data and other keyword arguments
h.set_yticklabels(h.get_yticklabels(), rotation = 0, fontsize = 10);
h.set_xticklabels(h.get_xticklabels(), rotation = 45, fontsize = 10);

# %% [markdown]
# How to measure the correlation between two __categorical__ features:
# <br>Using Theil’s U, also referred to as the Uncertainty Coefficient, is based on the conditional entropy between x and y. The output is in the range of [0,1].

# %%
import math
from collections import Counter
import scipy.stats as ss

def conditional_entropy(x,y):
    # entropy of x given y
    y_counter = Counter(y)
    xy_counter = Counter(list(zip(x,y)))
    total_occurrences = sum(y_counter.values())
    entropy = 0
    for xy in xy_counter.keys():
        p_xy = xy_counter[xy] / total_occurrences
        p_y = y_counter[xy[1]] / total_occurrences
        entropy += p_xy * math.log(p_y/p_xy)
    return entropy

def theil_u(x,y):
    s_xy = conditional_entropy(x,y)
    x_counter = Counter(x)
    total_occurrences = sum(x_counter.values())
    p_x = list(map(lambda n: n/total_occurrences, x_counter.values()))
    s_x = ss.entropy(p_x)
    if s_x == 0:
        return 1
    else:
        return (s_x - s_xy) / s_x

# %%
theilu = pd.DataFrame(index=['Survived'],columns=train_df.columns)
columns = train_df.columns
for j in range(0,len(columns)):
    u = theil_u(train_df['Survived'].tolist(),train_df[columns[j]].tolist())
    theilu.loc[:,columns[j]] = u
theilu.fillna(value=np.nan,inplace=True)
plt.figure(figsize=(20,1))
sns.heatmap(theilu,annot=True,fmt='.2f')
plt.show()

# %% [markdown]
# How to measure the correlation between a pair of a __continuous__ feature and a __categorical__ feature:
# <br> Mathematically, it is defined as the weighted variance of the mean of each category divided by the variance of all samples. In other words the Correlation Ratio answers the following question: Given a continuous number, how well can you know to which category it belongs to? The output is on the range of [0,1].

# %%
def correlation_ratio(categories, measurements):
    fcat, _ = pd.factorize(categories)
    cat_num = np.max(fcat)+1
    y_avg_array = np.zeros(cat_num)
    n_array = np.zeros(cat_num)
    for i in range(0,cat_num):
        cat_measures = measurements[np.argwhere(fcat == i).flatten()]
        n_array[i] = len(cat_measures)
        y_avg_array[i] = np.average(cat_measures)
    y_total_avg = np.sum(np.multiply(y_avg_array,n_array))/np.sum(n_array)
    numerator = np.sum(np.multiply(n_array,np.power(np.subtract(y_avg_array,y_total_avg),2)))
    denominator = np.sum(np.power(np.subtract(measurements,y_total_avg),2))
    if numerator == 0:
        eta = 0.0
    else:
        eta = np.sqrt(numerator/denominator)
    return eta

# %%
train_df.corr() #features; correlation (numerical features only)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
#correlation based on one parameter only (numerical features only)
train_df.corr().Survived.sort_values()
# Out:
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# PassengerId   -0.005007
# Parch          0.081629
# Fare           0.257307
# Survived       1.000000
# Name: Survived, dtype: float64

# %% [markdown]
# ### Distribution

# %%
sns.distplot(train_df['Age'], color='b', bins=30)
#kde: bool, optional. is a way to estimate the probability density function of a continuous random variable.
#   It is used when you need to know the distribution of the variable. 
#bins: argument for matplotlib hist(), or None, optional. Larger the bins the more accurate the result.

# %%
#distribution using pandas
train_df.Age.hist(alpha=0.7)

# %%
#seaborn.countplot(x=None, y=None, hue=None, data=None, color=None)
#Show the counts of observations in each categorical bin using bars.
#x, y, hue: names of variables in data or vector data, optional
#data: DataFrame, array, or list of arrays, optional. Dataset for plotting.
sns.countplot(train_df['Sex'])

# %%
#see if the our target is balances
sns.countplot(data=train_df, x="Survived", hue="Pclass")

# %% [markdown]
# __Catplot__ can handle 8 different plots currently available in Seaborn. catplot function can do all these types of plots and one can specify the type of plot one needs with the kind parameter.
# <br>The default kind in catplot() is “strip”, corresponding to stripplot(). Here are the list of different type of plots, involving categorical variables, you can make with catplot and the names of the kind.
# <br>Categorical __scatterplots__ with catplot: scatter plots are used to show how much one variable is affected by another.
# <br>-- stripplot() – with kind=”strip”
# <br>-- swarmplot() – with kind=”swarm”
# <br>Categorical __distribution__ plots with catplot: show distributions with respect to categories.
# <br>-- boxplot() – with kind=”box”
# <br>-- violinplot() – with kind=”violin”
# <br>-- boxenplot() – with kind=”boxen”
# <br>Categorical __estimate__ plots with catplot
# <br>-- pointplot() – with kind=”point”
# <br>-- barplot() – with kind=”bar”
# <br>-- countplot() – with kind=”count”

# %%
#seaborn.catplot(x=None, y=None, hue=None, size=None, data=None, palette=None,markers=None,kind='strip',height=5)
#For drawing categorical plots onto a FacetGrid.Shows the relationship between a numerical and one or more categorical variables
#The relationship between x and y can be shown for different subsets of the data using the hue, size, and style parameters
#x, y, hue: names of variables in data
#data: DataFrame
#kind: the kind of plot to draw. Options are: “point”, “bar”, “strip”, “swarm”, “box”, “violin”, “boxen”
#palette: palette name, list, or dict, optional.Colors to use for the different levels of the hue variable
sns.catplot(data=train_df, x="Survived", hue="Pclass", kind='count')

# %%
#scatter plot: This type of plots is used when you need to find a relation between two variables and 
#to find how the value of one variable changes the value of another variable.
#kind default is strip
sns.catplot(data=train_df, x="Pclass", y="Sex", hue="Survived")

# %% [markdown]
# A box plot shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. It can give all the stats provided in dataset .describe in a single plot. If the dataset is too large and the range of value is too big then it shows some values as outliers based on an inter-quartile function.
# <div>
# <img src="attachment:image.png" width="300"/>
# </div>

# %%
sns.catplot(data=train_df, x="Pclass", y="Sex", hue="Survived", kind='box')

# %%
sns.catplot(data=train_df, x="Pclass", y="Sex", hue="Survived", kind='violin')

# %%
#seaborn.relplot(x=None, y=None, hue=None, size=None, style=None, data=None, palette=None,markers=None,kind='scatter',height=5)
#This function provides access to several different axes-level functions that show the relationship between two variables
#The relationship between x and y can be shown for different subsets of the data using the hue, size, and style parameters
#x, y: names of variables in data; must be numeric.
#hue: name in data, optional. Grouping variable that will produce elements with different colors.
#   Can be either categorical or numeric
#kind: options: "scatter" (default, scatterplot()), "line" (lineplot())
#style: name in data, optional.Grouping variable that will produce elements with different styles. 
#   Can have a numeric dtype but will always be treated as categorical.
#data: DataFrame
#palette: palette name, list, or dict, optional.Colors to use for the different levels of the hue variable
sns.relplot(data=train_df, x="Fare", y="Age", hue="Survived")

# %%
sns.relplot(data=train_df, x="Fare", y="Age", hue="Survived", col='Sex')

# %%
#It shows the relationship between two variables in a dataset
sns.pairplot(train_df)

# %% [markdown]
# More on this can be found here https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %% [markdown]
# ### Access pandas DataFrame

# %% [markdown]
# Read this page first, intro to data structure https://pandas.pydata.org/pandas-docs/stable/getting_started/dsintro.html

# %% [markdown]
# Series is a one-dimensional labeled array capable of holding any data type (integers, strings, floating point numbers, Python objects, etc.). The axis labels are collectively referred to as the index. The basic method to create a Series is to call:
# <br> s = pd.Series(data, index=index)

# %%
s = pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'])

# %% [markdown]
#  A Series is like a fixed-size dict in that you can get and set values by index label

# %%
'e' in s
# Out:
# True

# %%
s['e']
# Out:
# -2.1854930022953103

# %% [markdown]
# __DataFrame__ is a 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL table, or a dict of Series objects. It is generally the most commonly used pandas object. Like Series, DataFrame accepts many different kinds of input

# %%
#The row and column labels can be accessed respectively by accessing the index and columns attributes
pd.DataFrame(train_df, index=[2,3], columns=['Name', 'Age'])
# Out:
#                                            Name   Age
# 2                                    Mary Aliza  26.0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="700"/>
# </div>

# %%
#pandas.DataFrame.select_dtypes(self, include=None, exclude=None) → 'DataFrame'
#Return a subset of the DataFrame’s columns based on the column dtypes.
objects_cols = train_df.select_dtypes("object").columns
# same as objects_cols = train_df.select_dtypes(include=["object"]).columns
print(objects_cols)
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
objects_cols = train_df.select_dtypes(include=["float64"]).columns
print(objects_cols)
# Out:
# Index(['Age', 'Fare'], dtype='object')

# %%
train_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
train_df['Name'] #access a column
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                                     10
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
train_df.Name #access a column
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                          Sara Alizadeh
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
#pandas.DataFrame.at[row, column]
#Access a single value for a row/column label pair.
#Use at if you only need to get or set a single value in a DataFrame or Series.
train_df.at[2, 'Name'] #Get value at specified row/column pair
# Out:
# 'Heikkinen, Miss. Laina'

# %%
#you can also set value at specified row/column pair
train_df.at[2, 'Name'] = 'Sara Alizadeh'
train_df.at[2, 'Name']
# Out:
# 'Sara Alizadeh'

# %%
#Get value within a Series
train_df.loc[2].at['Name']
# Out:
# 'Sara Alizadeh'

# %%
#pandas.DataFrame.loc[]
#Access a group of rows and columns by label(s) or a boolean array.
print(train_df.loc[2]) #single label returns the row as a Series. (row2)
# Out:
# PassengerId                   3
# Survived                      1
# Pclass                        3
# Name              Sara Alizadeh
# Sex                      female
# Age                          26
# SibSp                         0
# Parch                         0
# Ticket         STON/O2. 3101282
# Fare                      7.925
# Cabin                       NaN
# Embarked                      S
# Name: 2, dtype: object

# %%
print(train_df.loc[[2,3]])#list of labels (row2 and 3)
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                                 Sara Alizadeh  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
#
#              Ticket    Fare Cabin Embarked
# 2  STON/O2. 3101282   7.925   NaN        S
# 3            113803  53.100  C123        S

# %%
print(train_df.loc[2:5])#list of labels (row2 to 5)
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                                 Sara Alizadeh  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q

# %%
print(train_df.loc[2,'Name']) #single label for row and column (row2, column Name)
#same as train_df.at[2,'Name']
# Out:
# Sara Alizadeh

# %%
train_df.loc[train_df['Age'] < 2] #Conditional that returns a boolean Series
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 164          165         0       3     Panula, Master. Eino Viljami    male
# 172          173         1       3     Johnson, Miss. Eleanor Ileen  female
# 183          184         1       2        Becker, Master. Richard F    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 381          382         1       3      Nakid, Miss. Maria ("Mary")  female
# 386          387         0       3  Goodwin, Master. Sidney Leonard    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 788          789         1       3       Dean, Master. Bertram Vere    male
# ...

# %%
#Conditional that returns a boolean Series with column labels specified
train_df.loc[train_df['Age'] < 2, ['Name', 'Age']]
# Out:
#                                 Name   Age
# 78     Caldwell, Master. Alden Gates  0.83
# 164     Panula, Master. Eino Viljami  1.00
# 172     Johnson, Miss. Eleanor Ileen  1.00
# 183        Becker, Master. Richard F  1.00
# 305   Allison, Master. Hudson Trevor  0.92
# 381      Nakid, Miss. Maria ("Mary")  1.00
# 386  Goodwin, Master. Sidney Leonard  1.00
# 469    Baclini, Miss. Helene Barbara  0.75
# 644           Baclini, Miss. Eugenie  0.75
# 755        Hamalainen, Master. Viljo  0.67
# 788       Dean, Master. Bertram Vere  1.00
# 803  Thomas, Master. Assad Alexander  0.42
# 827            Mallet, Master. Andre  1.00
# 831  Richards, Master. George Sibley  0.83

# %%
#Callable that returns a boolean Series
train_df.loc[lambda train_df: train_df['Age'] == 2]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 7              8         0       3     Palsson, Master. Gosta Leonard    male
# 16            17         0       3               Rice, Master. Eugene    male
# 119          120         0       3  Andersson, Miss. Ellis Anna Maria  female
# 205          206         0       3         Strom, Miss. Telma Matilda  female
# 297          298         0       1       Allison, Miss. Helen Loraine  female
# 340          341         1       2     Navratil, Master. Edmond Roger    male
# 479          480         1       3           Hirvonen, Miss. Hildur E  female
# 530          531         1       2           Quick, Miss. Phyllis May  female
# 642          643         0       3      Skoog, Miss. Margit Elizabeth  female
# 824          825         0       3       Panula, Master. Urho Abraham    male
#
#      Age  SibSp  Parch   Ticket      Fare    Cabin Embarked
# ...

# %%
women = train_df.loc[(train_df.Sex == 'female') & (train_df.Age == 22.0), ["Survived"] ]
print(women)
# Out:
#      Survived
# 141         1
# 151         1
# 289         1
# 323         1
# 356         1
# 376         1
# 474         0
# 539         1
# 554         1
# 608         1
# 708         1
# 882         0

# %%
#Set value for all items matching the list of labels
train_df.loc[[2,3], ['Name']] = 'Sara'

# %%
#Set value for an entire row
train_df.loc[2] = 10
train_df.loc[2]
# Out:
# PassengerId    10
# Survived       10
# Pclass         10
# Name           10
# Sex            10
# Age            10
# SibSp          10
# Parch          10
# Ticket         10
# Fare           10
# Cabin          10
# Embarked       10
# Name: 2, dtype: object

# %%
#Set value for an entire column
train_df.loc[:, 'Age'] = 30
train_df.loc[:, 'Age']
# Out:
# 0      30
# 1      30
# 2      30
# 3      30
# 4      30
#        ..
# 886    30
# 887    30
# 888    30
# 889    30
# 890    30
# Name: Age, Length: 891, dtype: int64

# %%
#Set value for rows matching callable condition
train_df.loc[train_df['Name'] == 'Sara Alizadeh', ['Name']] = 'Mary Aliza'

# %%
train_df.loc[ train_df['Name'] == 'Mary Aliza']
# Out:
#    PassengerId  Survived  Pclass        Name     Sex   Age  SibSp  Parch  \
# 2            3         1       3  Mary Aliza  female  26.0      0      0
#
#              Ticket   Fare Cabin Embarked
# 2  STON/O2. 3101282  7.925   NaN        S

# %%
#MultiIndex object is like the standard Index object which stores the axis labels in pandas objects. 
#You can think of MultiIndex as an array of tuples where each tuple is unique.
#A MultiIndex can be created from a list of arrays (using MultiIndex.from_arrays()), 
#an array of tuples (using MultiIndex.from_tuples()), a crossed set of iterables (using MultiIndex.from_product()), 
#or a DataFrame (using MultiIndex.from_frame()). 
tuples = [
   ('cobra', 'mark i'), ('cobra', 'mark ii'),
   ('sidewinder', 'mark i'), ('sidewinder', 'mark ii'),
   ('viper', 'mark ii'), ('viper', 'mark iii')
]
index = pd.MultiIndex.from_tuples(tuples)
values = [[12, 2], [0, 4], [10, 20],
        [1, 4], [7, 1], [16, 36]]
df = pd.DataFrame(values, columns=['max_speed', 'shield'], index=index)
df
# Out:
#                      max_speed  shield
# cobra      mark i           12       2
#            mark ii           0       4
# sidewinder mark i           10      20
#            mark ii           1       4
# viper      mark ii           7       1
#            mark iii         16      36

# %%
#Single label. Note this returns a DataFrame with a single index.
df.loc['cobra']
# Out:
#          max_speed  shield
# mark i          12       2
# mark ii          0       4

# %%
#Single index tuple. Note this returns a Series.
df.loc[('cobra', 'mark ii')]
# Out:
# max_speed    0
# shield       4
# Name: (cobra, mark ii), dtype: int64

# %%
#Single tuple. Note using [[]] returns a DataFrame.
df.loc[[('cobra', 'mark ii')]]
# Out:
#                max_speed  shield
# cobra mark ii          0       4

# %%
#Single tuple for the index with a single label for the column
df.loc[('cobra', 'mark i'), 'shield']
# Out:
# 2

# %%
#Slice from index tuple to single label
df.loc[('cobra', 'mark i'):'viper']
# Out:
#                      max_speed  shield
# cobra      mark i           12       2
#            mark ii           0       4
# sidewinder mark i           10      20
#            mark ii           1       4
# viper      mark ii           7       1
#            mark iii         16      36

# %%
#Slice from index tuple to index tuple
df.loc[('cobra', 'mark i'):('viper', 'mark ii')]
# Out:
#                     max_speed  shield
# cobra      mark i          12       2
#            mark ii          0       4
# sidewinder mark i          10      20
#            mark ii          1       4
# viper      mark ii          7       1

# %%
#pandas.concat()
#Concatenate pandas objects along a particular axis with optional set logic along the other axes
#like join in sql
#axis: 0/’index’, 1/’columns’, default 0. The axis to concatenate along.
train_df_2 = pd.concat([train_df, sex, embarked], axis=1)

# %%
#pandas.DataFrame.drop(self, labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise')
#Drop specified labels from rows or columns.
#axis: 0 or ‘index’, 1 or ‘columns’, default 0
#inplace: bool, default False. If True, do operation inplace and return None.
train_df = train_df.drop(["PassengerId", "Name", "Ticket", "Cabin"], axis=1)

# %%
cols_with_missing = [col for col in X_train_full.columns if X_train_full[col].isnull().any()] 
X_train_full.drop(cols_with_missing, axis=1, inplace=True)

# %%
# "Cardinality" means the number of unique values in a column
# Get number of unique entries in each column with categorical data
object_nunique = list(map(lambda col: X_train[col].nunique(), object_cols))
d = dict(zip(object_cols, object_nunique))
# Print number of unique entries by column, in ascending order
sorted(d.items(), key=lambda x: x[1])

# Select categorical columns with relatively low cardinality (convenient but arbitrary)
low_cardinality_cols = [cname for cname in X_train_full.columns if 
                        X_train_full[cname].nunique() < 10 and 
                        X_train_full[cname].dtype == "object"]

# %% [markdown]
# # scikit learn

# %%
#Machine learning library
#from sklearn ...

# %% [markdown]
# ### dealing with missing values

# %%
#drop the null values
train_df = train_df.dropna() #defualt is 0 so it is row wise

# %%
#pandas.DataFrame.fillna(self, value=None, method=None, axis=None, inplace=False, limit=None, downcast=None)
#Fill (propogate) NA/NaN values using the specified method.
#method: {‘backfill’, ‘bfill’, ‘pad’, ‘ffill’, None}, default None
#ffill: propagate last valid observation forward to next valid backfill
#bfill: use next valid observation to fill gap.
#axis: {0 or ‘index’, 1 or ‘columns’}. Axis along which to fill missing values.
#inplace: bool, default False
train_df.fillna(method='ffill', inplace=True)

# %%
#custome version
#Age and Pclass are correlated so we estimate the missing Age based on Pclass
def predict_age(row_age_pclass):
    age = row_age_pclass[0]
    pclass = row_age_pclass[1]
    if pd.isnull(age):
        if pclass == 1:
            return 38
        elif pclass == 2:
            return 29
        else:
            return 25
    else:
        return age 
#apply: get a column and apply a change row by row
train_df['Age'] = train_df[['Age', 'Pclass']].apply(predict_age, axis=1)

# %%
#SimpleImputer: sklearn library for Imputation of missing values You Can find all of them here: 
#https://scikit-learn.org/stable/modules/impute.html#univariate-feature-imputation
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(np.nan, "mean")
train_df['Age'] = imputer.fit_transform(np.array(train_df['Age']).reshape(891, 1))

# Imputation
my_imputer = SimpleImputer()
imputed_X_train = pd.DataFrame(my_imputer.fit_transform(X_train))
imputed_X_valid = pd.DataFrame(my_imputer.transform(X_valid))

# Imputation removed column names; put them back
imputed_X_train.columns = X_train.columns
imputed_X_valid.columns = X_valid.columns

# %% [markdown]
# ### dealing with object features

# %%
#pandas.get_dummies(data,prefix=None,prefix_sep='_',dummy_na=False,columns=None,sparse=False,drop_first=False,dtype=None)→DataFrame
#Convert categorical variable into dummy/indicator variables.
#drop_firstbool, default False. Whether to get k-1 dummies out of k categorical levels by removing the first level.
sex = pd.get_dummies(train_df['Sex'], drop_first=True)
embarked = pd.get_dummies(train_df['Embarked'], drop_first=True)

# %%
#columns with "object" data type must convert to numbers.
objects_cols = train_df.select_dtypes("object").columns

#Encode target labels with value between 0 and (n_classes - 1)
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
train_df[objects_cols] = train_df[objects_cols].apply(le.fit_transform)

# %%
#one-hot encoder
from sklearn.preprocessing import OneHotEncoder
OH_encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)
OH_cols_train = pd.DataFrame(OH_encoder.fit_transform(X_train[object_cols]))
# One-hot encoding removed index; put it back
OH_cols_train.index = X_train.index
# Remove categorical columns (will replace with one-hot encoding)
num_X_train = X_train.drop(object_cols, axis=1)
# Add one-hot encoded columns to numerical features
OH_X_train = pd.concat([num_X_train, OH_cols_train], axis=1)

# %% [markdown]
# ### normalizing

# %% [markdown]
# ### standardizing

# %%
#Scaling: standardize features by removing the mean and scaling to unit variance
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
scale.fit(X)
X = scale.transform(X)

# %% [markdown]
# ### split data

# %%
#split the data to training and test
from sklearn.model_selection import train_test_split
X = train_df.drop('Survived', axis=1)
y = train_df.Survived
#split the training data t0 70%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42

# %% [markdown]
# ### evaluation

# %%
#1
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, logmodel_predict))
print(confusion_matrix(y_test, logmodel_predict))
#2
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_pred, y_test)
print(f"{self.model_name()} Model Accuracy: ", acc)

#cross validarion
from sklearn.model_selection import cross_val_score
CVS = cross_val_score(self.model, self.X, self.y, scoring='accuracy', cv=cv)
print(CVS)
print("="*60, "\nMean accuracy of cross-validation: ", CVS.mean())

# %% [markdown]
# ### ML algorithms

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
#train
logmodel.fit(X_train, y_train)
#predict
logmodel_predict = logmodel.predict(X_test)
#evaluate
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, logmodel_predict))
print(confusion_matrix(y_test, logmodel_predict))

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier
#train
randmodel = RandomForestClassifier(n_estimators=200, max_depth=10, random_state=1)
randmodel.fit(X_train, y_train)
#predict
randmodel_predict = randmodel.predict(X_test)

# %%
#SVC
from sklearn.svm import SVC
svc_model = SVC()
#train
svc_model.fit(X_train, y_train)
#predict
svc_predict = svc_model.predict(X_test)

# %%
#GaussianNB
from sklearn.naive_bayes import GaussianNB

# %%
from xgboost import XGBClassifier
from xgboost import XGBRegressor
my_model = XGBRegressor(n_estimators=1000, learning_rate=0.05, n_jobs=4)
my_model.fit(X_train, y_train, 
             early_stopping_rounds=5, 
             eval_set=[(X_valid, y_valid)], 
             verbose=False)

# %% [markdown]
# # tensorflow

# %%
import tensorflow as tf

#Neural Network
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout

X_train_nn = X_train.values
y_train_nn = y_train.values
X_test_nn = X_test.values
y_test_nn = y_test.values

nn_model = Sequential()
#add layer
nn_model.add(Dense(units=8, activation='relu')) #unit is the # nodes which is roughly # of features
nn_model.add(Dropout(0.5)) #prevent NN from overfitting by disabling 50% of the activation nodes
#add layer
nn_model.add(Dense(units=4, activation='relu'))
nn_model.add(Dropout(0.5)) 
#add layer (final layer)
nn_model.add(Dense(units=1, activation='sigmoid'))
nn_model.compile(loss='binary_crossentropy', optimizer='adam')
#if model not working stop before the iterations (epochs)
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
#train
nn_model.fit(x=X_train_nn, y=y_train_nn, epochs=200, validation_data=(X_test_nn, y_test_nn), verbose=1, callbacks=[early_stop])

# %% [markdown]
# ### image

# %%
import numpy as np
from tensorflow.python.keras.applications.resnet50 import preprocess_input
from tensorflow.python.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications import VGG16

image_size = 224

def read_and_prep_images(img_paths, img_height=image_size, img_width=image_size):
    imgs = [load_img(img_path, target_size=(img_height, img_width)) for img_path in img_paths]
    img_array = np.array([img_to_array(img) for img in imgs])
    output = preprocess_input(img_array)
    return(output)
#Create Model with Pre-Trained Weights File. Make Predictions
from tensorflow.python.keras.applications import ResNet50

my_model = ResNet50(weights='../input/resnet50/resnet50_weights_tf_dim_ordering_tf_kernels.h5')
test_data = read_and_prep_images(img_paths)
preds = my_model.predict(test_data)
Visualize Predictions
from learntools.deep_learning.decode_predictions import decode_predictions
from IPython.display import Image, display

most_likely_labels = decode_predictions(preds, top=3, class_list_path='../input/resnet50/imagenet_class_index.json')

for i, img_path in enumerate(img_paths):
    display(Image(img_path))
    print(most_likely_labels[i])

# %% [markdown]
# # pipeline

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

# Preprocessing for numerical data
numerical_transformer = SimpleImputer(strategy='constant')
# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])
# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])
model = RandomForestRegressor(n_estimators=100, random_state=0)
# Bundle preprocessing and modeling code in a pipeline
my_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                              ('model', model)
                             ])
# Preprocessing of training data, fit model 
my_pipeline.fit(X_train, y_train)
# Preprocessing of validation data, get predictions
preds = my_pipeline.predict(X_valid)
